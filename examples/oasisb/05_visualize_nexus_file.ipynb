# %%
import os
from jupyterlab_h5web import H5Web
from pynxtools._version import version as pynx_core_version
from pynxtools_apm._version import version as pynx_apm_version

print(f"pynxtools: {pynx_core_version}")
print(f"pynxtools-apm: {pynx_apm_version}")

with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}".replace(
        "decompressed", "nexus_hfive"
    )
print(trg_directory)

# %%
H5Web(f"{trg_directory}{os.sep}aus_sydney_bilal.0.output.nxs")
