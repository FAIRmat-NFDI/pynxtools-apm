# %%
import os
from jupyterlab_h5web import H5Web
print(os.getcwd())
with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0:trg_directory.rfind('/')]}"
print(prefix)

file_path = f"{prefix}{os.sep}apm_prepare_nomad_v142{os.sep}aus_sydney_bilal.0.output.nxs"  # aus_curtin_fougerouse_arsenopyrite.0.output.nxs"  # aus_canberra_magee.0.output.nxs"  # deu_saarbruecken_pauly.0.output.nxs"
print(file_path)
H5Web(file_path)
# Out:
# /home/kaiobach/Research/hu_hu_hu/sprint_cameca/pynx-apm/pynxtools-apm/examples/oasisb
# /media/kaiobach/production/scidat_nomad_apt
# /media/kaiobach/production/scidat_nomad_apt/apm_prepare_nomad_v142/aus_sydney_bilal.0.output.nxs
