# %%
import os
from jupyterlab_h5web import H5Web
print(os.getcwd())
with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0:trg_directory.rfind('/')]}"
print(prefix)

file_path = f"{prefix}{os.sep}apm_prepare_nomad_v142{os.sep}deu_saarbruecken_pauly.0.output.nxs"
print(file_path)
H5Web(file_path)
