# %%
import os

from jupyterlab_h5web import H5Web

print(os.getcwd())
with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}"
print(prefix)

file_path = f"{prefix}{os.sep}apm_prepare_nomad_v142{os.sep}usa_cameca_ulfig.0.output.nxs"  # aus_canberra_magee.0.output.nxs"  # deu_saarbruecken_pauly.0.output.nxs"  # aus_sydney_bilal.0.output.nxs"  # aus_curtin_fougerouse_arsenopyrite.0.output.nxs"  # aus_canberra_magee.0.output.nxs"  # d
print(file_path)
H5Web(file_path)
