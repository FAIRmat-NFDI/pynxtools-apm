# %%
import os

from jupyterlab_h5web import H5Web

print(os.getcwd())
with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}{os.sep}pynxtools"
print(prefix)

file_paths = [
    # "aus_canberra_magee.0.nxs",
    # "aus_sydney_breen.0.nxs",
    # "aus_sydney_cairney.0.nxs",
    # "aus_sydney_bilal.0.nxs",
    # "jpn_nims_uzuhashi_05.0.nxs",
    # "deu_saarbruecken_pauly.0.nxs",
    # "usa_idaho_boise_08.0.nxs",
    # "aus_sydney_lafontaine.1.nxs",
    # "usa_urbana_chatterjee.5.nxs",
]
H5Web(f"{prefix}{os.sep}{file_paths[0]}")
