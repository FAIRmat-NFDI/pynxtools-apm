# %%
import os

from jupyterlab_h5web import H5Web

print(os.getcwd())
with open("target_directory.txt") as fp:
    trg_directory = f"{fp.read().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}{os.sep}pynxtools"
print(prefix)

# file_path = f"{prefix}{os.sep}aus_canberra_magee.0.nxs"
# file_path = f"{prefix}{os.sep}aus_sydney_bilal.0.nxs"
# file_path = f"{prefix}{os.sep}jpn_nims_uzuhashi_05.0.nxs"
# file_path = f"{prefix}{os.sep}deu_saarbruecken_pauly.0.nxs"
# file_path = f"{prefix}{os.sep}usa_idaho_boise_08.0.nxs"
file_path = f"{prefix}{os.sep}aus_sydney_lafontaine.0.nxs"
print(file_path)
H5Web(file_path)
